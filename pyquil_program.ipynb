# %%
from pyquil import get_qc, Program
from pyquil.gates import CNOT, Z, MEASURE
from pyquil.api import local_forest_runtime
from pyquil.quilbase import Declare

prog = Program(
    Declare("ro", "BIT", 2),
    Z(0),
    CNOT(0, 1),
    MEASURE(0, ("ro", 0)),
    MEASURE(1, ("ro", 1)),
).wrap_in_numshots_loop(10)

with local_forest_runtime():
    qvm = get_qc('9q-square-qvm')
    bitstrings = qvm.run(qvm.compile(prog)).readout_data.get("ro")
# Out:
# C:\Users\fabri\AppData\Local\Temp\ipykernel_2944\2137618160.py:16: DeprecationWarning: Call to deprecated function (or staticmethod) readout_data. (This property is ambiguous now that the `get_raw_readout_data()` method exists and will be removed in future versions. Use the `get_register_map()` method instead.) -- Deprecated since version 4.0.0.
#   bitstrings = qvm.run(qvm.compile(prog)).readout_data.get("ro")

# %%
from pyquil import get_qc, Program
from pyquil.gates import CNOT, H, MEASURE
 
qvm = get_qc('2q-qvm')
 
p = Program()
p += H(0)
p += CNOT(0, 1)
ro = p.declare('ro', 'BIT', 2)
p += MEASURE(0, ro[0])
p += MEASURE(1, ro[1])
p.wrap_in_numshots_loop(10)

qvm.run(p).get_register_map()['ro'].tolist()
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_exceptions.py", line 10, in map_exceptions
#     yield
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\backends\sync.py", line 94, in connect_tcp
#     sock = socket.create_connection(
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\socket.py", line 845, in create_connection
#     raise err
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\socket.py", line 833, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_transports\default.py", line 60, in map_httpcore_exceptions
#     yield
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_transports\default.py", line 218, in handle_request
#     resp = self._pool.handle_request(req)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection_pool.py", line 253, in handle_request
#     raise exc
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection_pool.py", line 237, in handle_request
#     response = connection.handle_request(request)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection.py", line 86, in handle_request
#     raise exc
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection.py", line 63, in handle_request
#     stream = self._connect(request)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_sync\connection.py", line 111, in _connect
#     stream = self._network_backend.connect_tcp(**kwargs)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\backends\sync.py", line 93, in connect_tcp
#     with map_exceptions(exc_map):
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc)
# httpcore.ConnectError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3548, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\fabri\AppData\Local\Temp\ipykernel_11324\49914673.py", line 4, in <module>
#     qvm = get_qc('2q-qvm')
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_quantum_computer.py", line 822, in get_qc
#     prefix, qvm_type, noisy = _parse_name(name, as_qvm, noisy)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_quantum_computer.py", line 669, in _get_unrestricted_qvm
#     :param compiler_timeout: Time limit for compilation requests, in seconds.
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_quantum_computer.py", line 598, in _get_qvm_with_topology
#     qvm_type=qvm_type,
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_quantum_computer.py", line 551, in _get_qvm_qc
#     ),
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_quantum_computer.py", line 517, in _get_qvm_or_pyqvm
#     def _get_qvm_qc(
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_qvm.py", line 116, in __init__
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_qvm.py", line 120, in connect
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_qvm.py", line 175, in get_version_info
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_qvm_client.py", line 176, in get_version
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\pyquil\api\_qvm_client.py", line 259, in _post_json
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py", line 1136, in post
#     return self.request(
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py", line 821, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py", line 908, in send
#     response = self._send_handling_auth(
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py", line 936, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py", line 973, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_client.py", line 1009, in _send_single_request
#     response = transport.handle_request(request)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_transports\default.py", line 217, in handle_request
#     with map_httpcore_exceptions():
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "e:\Users\fabri\AppData\Local\Programs\Python\Python310\lib\site-packages\httpx\_transports\default.py", line 77, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 2142, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#   File "C:\Users\fabri\AppData\Roaming\Python\Python310\site-packages\executing\executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
